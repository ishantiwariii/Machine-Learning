# %% [markdown]
# ## regression model

# %% [markdown]
# ### OlS model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Machine Learning\regression analysis\diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x = df.drop(columns="Outcome" , axis=1)
y = df["Outcome"]

x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=45)

# %% [markdown]
# ### Statistic analysis for model selection

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(x_train)

# %%
model = sm.OLS(y_train,X)
result = model.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Outcome   R-squared:                       0.327
# Model:                            OLS   Adj. R-squared:                  0.318
# Method:                 Least Squares   F-statistic:                     36.73
# Date:                Sat, 28 Feb 2026   Prob (F-statistic):           1.65e-47
# Time:                        20:14:52   Log-Likelihood:                -297.15
# No. Observations:                 614   AIC:                             612.3
# Df Residuals:                     605   BIC:                             652.1
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -0.9311      0.094     -9.951      0.000      -1.115      -0.747
# ...

# %%
# dropping some insignificant columns
x = x.drop(['SkinThickness','Insulin', 'Age'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
#       1 # dropping some insignificant columns
# ----> 2 x = x.drop(['SkinThickness','Insulin', 'Age'], axis=1)
#
# File c:\Users\ieish\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
# ...

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure   BMI  DiabetesPedigreeFunction
# 0            6      148             72  33.6                     0.627
# 1            1       85             66  26.6                     0.351
# 2            8      183             64  23.3                     0.672
# 3            1       89             66  28.1                     0.167
# 4            0      137             40  43.1                     2.288

# %%
X = sm.add_constant(x)

# %%
model = sm.OLS(y,X)

# %%
resultl = model.fit()

# %%
print(resultl.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Outcome   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     64.92
# Date:                Sat, 28 Feb 2026   Prob (F-statistic):           1.76e-56
# Time:                        20:16:49   Log-Likelihood:                -384.39
# No. Observations:                 768   AIC:                             780.8
# Df Residuals:                     762   BIC:                             808.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -0.7966      0.082     -9.765      0.000      -0.957      -0.636
# ...
